# %%
from OTClab.finlab.data import Data
data = Data()
close = data.get('收盤價',30)
close.
# Out:
# stock_id     0050   0051   0052   0053   0054   0055   0056   0057   0058  \
# date
# 2018-12-10  74.45  28.77  47.52  30.24  19.31  16.59  24.07  45.28  41.11
# 2018-12-11  75.05  28.87  48.01  30.56  19.34  16.64  24.18  45.54  40.82
# 2018-12-12  76.20  30.50  48.65  30.86  19.81  16.70  24.32  46.16  41.42
# 2018-12-13  76.30  29.37  49.04  31.26  19.81  16.75  24.39  46.43  41.66
# 2018-12-14  75.35  29.16  48.00  30.74  19.72  16.70  24.31  45.70  41.24
#
# stock_id     0059  ...    9940  9941  9941A  9942  9943   9944   9945   9946  \
# date               ...
# 2018-12-10  42.19  ...   29.70  88.6   50.9  69.2  58.3  16.55  46.80  12.30
# 2018-12-11  41.91  ...   30.15  88.9   51.0  68.2  58.2  16.15  47.00  12.25
# 2018-12-12  41.70  ...   30.60  90.5   51.0  67.3  58.1  16.25  47.45  12.35
# 2018-12-13  42.11  ...   30.40  92.5   51.0  67.3  57.9  16.30  47.90  12.50
# 2018-12-14  41.72  ...   30.05  92.7   51.0  67.8  57.9  16.30  47.25  12.60
#
# stock_id     9955  9958
# ...

# %%
def crawl_OTC_price(date):
    datestr = date.strftime('%Y%m%d')
    try:
        link = 'http://www.tpex.org.tw/web/stock/aftertrading/daily_close_quotes/stk_quote_result.php?l=zh-tw&o=htm&d='+ datestr+'&s=0,asc,0'
        r = requests.post(link)
    except:
        print('**WARRN: cannot get stock price at', datestr)
        return None
    
    lines = r.text.replace('\r', '').split('\n')
    df = pd.read_csv(StringIO("\n".join(lines[3:])), sep=',', delimiter=',', header=None)
    df.columns = list(map(lambda l: l.replace(' ',''), lines[2].split(',')))
    df.index = df['代號']
    df = df.drop(['代號'], axis=1)
    
    return df

# %%
from OTClab.finlab.data import Data
data = Data()
close = data.get('收盤價',30)
close.head()
# Out:
# stock_id     0050   0051   0052   0053   0054   0055   0056   0057   0058  \
# date
# 2018-11-05  78.25  29.37  49.88  32.41  20.91  17.42  24.18  47.34  42.80
# 2018-11-06  78.00  29.33  48.50  32.05  20.71  17.43  24.08  47.02  42.40
# 2018-11-07  78.40  29.71  49.84  32.26  20.79  17.61  24.21  47.30  42.37
# 2018-11-08  78.85  29.71  50.25  32.41  20.90  17.76  24.37  47.72  42.61
# 2018-11-09  77.80  29.42  49.04  31.91  20.58  17.75  24.21  47.02  42.05
#
# stock_id     0059  ...    9940  9941  9941A  9942  9943   9944   9945   9946  \
# date               ...
# 2018-11-05    NaN  ...   29.55  84.5    NaN  72.0  57.0  16.00  43.00  11.30
# 2018-11-06  42.11  ...   29.60  84.5    NaN  72.0  57.0  16.00  42.65  11.20
# 2018-11-07  42.26  ...   29.95  85.0    NaN  72.0  57.6  16.10  43.00  11.25
# 2018-11-08  42.58  ...   30.40  88.5    NaN  71.9  57.6  16.55  44.25  11.35
# 2018-11-09  43.05  ...   30.50  87.7    NaN  70.9  57.8  16.50  43.85  11.60
#
# stock_id     9955  9958
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '1107'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-a9627cd8837a> in <module>()
# ----> 1 close['1107']
#
# ...

# %%
import requests
import pandas as pd
from io import StringIO
def crawl_OTC_price(date):
    datestr = date.strftime('%Y%m%d')
  
    link = 'http://www.tpex.org.tw/web/stock/aftertrading/daily_close_quotes/stk_quote_result.php?l=zh-tw&o=htm&d='+ datestr+'&s=0,asc,0'
    r = requests.post(link)
#     except:
#         print('**WARRN: cannot get stock price at', datestr)
#         return None
    
    lines = r.text.replace('\r', '').split('\n')
    df = pd.read_csv(StringIO("\n".join(lines[3:])), sep=',', delimiter=',', header=None)
    df.columns = list(map(lambda l: l.replace(' ',''), lines[2].split(',')))
    df.index = df['代號']
    df = df.drop(['代號'], axis=1)
    
    return df

# %%
datestr = d.strftime('%Y%m%d')
Y = int(datestr[:4])-1911
Y = str(Y)
M = datestr[4:6]
D = datestr[6:]
datestr = Y + '/' + M + '/' + D
# Out:
# '107/12/17'

# %%
from bs4 import BeautifulSoup
datestr = d.strftime('%Y%m%d')
datestr = d.strftime('%Y%m%d')
Y = int(datestr[:4])-1911
Y = str(Y)
M = datestr[4:6]
D = datestr[6:]
datestr = Y + '/' + M + '/' + D
link = 'http://www.tpex.org.tw/web/stock/aftertrading/daily_close_quotes/stk_quote_result.php?l=zh-tw&o=htm&d='+ datestr+'&s=0,asc,0'
r = requests.post(link)
#     except:
#         print('**WARRN: cannot get stock price at', datestr)
#         return None

# lines = r.text.replace('\r', '').split('\n')
# df = pd.read_csv(StringIO("\n".join(lines[3:])), sep=',', delimiter=',', header=None)
# df.columns = list(map(lambda l: l.replace(' ',''), lines[2].split(',')))
# df.index = df['代號']
# df = df.drop(['代號'], axis=1)

# %%
content  = r.text
#content = content.replace('\t' , "").replace('n',"")
soup = BeautifulSoup(content,'lxml')
divs = soup.findAll(class_ = 'table-head-center')
# for div in divs:
#     price = div.get_text()
#     print(price)
#     print('-----')

# %%
# import datetime
# d = datetime.date(2018,12,17)
# df1 = crawl_OTC_price(d)
